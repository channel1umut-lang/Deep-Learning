# %% [markdown]
# <a href="https://colab.research.google.com/github/channel1umut-lang/Deep-Learning/blob/main/0002_PyTorchFundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
# pytorch datatypes - tensors

# %%
torch.tensor(10)
# Out:
# tensor(10)

# %%
scalar = torch.tensor(10)

# %%
type(scalar)
# Out:
# torch.Tensor

# %%
scalar + 5
# Out:
# tensor(15)

# %%
scalar - 10
# Out:
# tensor(0)

# %%
scalar
# Out:
# tensor(10)

# %%
scalar.dim() # sifir boyutlu matrix
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
scalar.item()
# Out:
# 10

# %%
type(scalar.item())
# Out:
# int

# %%
numpy_int = np.int32(10)

# %%
numpy_int
# Out:
# np.int32(10)

# %%
numpy_int + 10
# Out:
# np.int32(20)

# %%
numpy_int * 20
# Out:
# np.int32(200)

# %%
scalar_from_np = torch.tensor(numpy_int)

# %%
scalar_from_np
# Out:
# tensor(10, dtype=torch.int32)

# %%
# dtype seems int32

# %%
scalar.dtype
# Out:
# torch.int64

# %%
#default seems to be 64, let's see how we can create a tensor with 32 bit with a regular int rather than np

# %%
new_scalar = torch.tensor(25, dtype=torch.int32)

# %%
new_scalar
# Out:
# tensor(25, dtype=torch.int32)

# %%
new_scalar + 10
# Out:
# tensor(35, dtype=torch.int32)

# %%
tensor_float = torch.tensor(3.14)

# %%
tensor_float
# Out:
# tensor(3.1400)

# %%
tensor_float.dtype # default degeri 64 bit
# Out:
# torch.float32

# %%
tensor_float_64 = torch.tensor(3.14, dtype=torch.float64) # saklama kapasitesini degistirmek icin kullaniriz yani default degere degistirebiliyoruz.

# %%
tensor_float_64
# Out:
# tensor(3.1400, dtype=torch.float64)

# %%
# vectors

# %%
vector = torch.tensor([2, 3])

# %%
vector
# Out:
# tensor([2, 3])

# %%
vector.dim()#function
# Out:
# 1

# %%
vector.ndim # attribute, 1 boyutlu yani sadece 1 kolonu ve voklu satirlari olan matrix gibi dusunebilirsin.
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
vector = torch.tensor([1,2,3])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([3])

# %%
# count # of [ in order to figure out number of dimensions # yani koseli parantez sayisi boyut sayisini veriyor. Icindeki sayi da icindeki eleman sayisini veriyor.
# count elements in order to figure out shape

# %%
matrix = torch.tensor([[1,2],[3,4]])

# %%
matrix.ndim
# Out:
# 2

# %%
matrix.shape
# Out:
# torch.Size([2, 2])

# %%
tensor_example = torch.tensor([[[1,2,3],[3,4,5],[4,5,6]]])

# %%
tensor_example
# Out:
# tensor([[[1, 2, 3],
#          [3, 4, 5],
#          [4, 5, 6]]])

# %%
tensor_example.ndim
# Out:
# 3

# %%
tensor_example.shape
# Out:
# torch.Size([1, 3, 3])

# %%
# this means 1 dimension of 3 by 3

# %%
tensor_example_2 = torch.tensor([[[1,2,3],[3,4,5],[4,5,6]],[[1,2,3],[3,4,5],[4,5,6]]])

# %%
tensor_example_2
# Out:
# tensor([[[1, 2, 3],
#          [3, 4, 5],
#          [4, 5, 6]],
#
#         [[1, 2, 3],
#          [3, 4, 5],
#          [4, 5, 6]]])

# %%
tensor_example.ndim
# Out:
# 3

# %%
tensor_example_2.shape #yani 1. boyuttan 3 eleman(yani sira). 2. boyuttan 3 eleman(yani kolon sayisi). 3. boyuttan 2 eleman(yani derinlik sayisi)
# Out:
# torch.Size([2, 3, 3])

# %%
# deep dive into dtypes - https://docs.pytorch.org/docs/stable/tensors.html#data-types

# %%
float_32_tensor = torch.tensor([3.0, 6.0, 9.0],
                               dtype=None, # default or custom? yani degiskenin default degerini atar yani int32 mi float 32 mi vs...
                               device=None, # cpu, gpu? bunlardan hangisini kullanacagini secebiliyorsun.
                               requires_grad=False) # If autograd should record operations on the returned tensor # yani true yaptigimizda ogrenecek false yaptigimizda ogrenmeyecek.

# %%
float_32_tensor.shape
# Out:
# torch.Size([3])

# %%
float_32_tensor.dtype
# Out:
# torch.float32

# %%
float_32_tensor.device
# Out:
# device(type='cpu')

# %%
float_16_tensor = torch.tensor([3.0, 6.0, 9.0],
                               dtype=torch.float16)

# %%
float_16_tensor.dtype
# Out:
# torch.float16
